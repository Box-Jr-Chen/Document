# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# 无监督学习，只有分类
from sklearn.cluster import KMeans

# %%
import sklearn.datasets as datasets

# %%
X,y = datasets.make_blobs()

plt.scatter(X[:,0],X[:,1],c = y)

# %%
X
# Out:
# array([[-3.8066092 , -3.4221093 ],
#        [-0.17892194, -3.58882879],
#        [-4.43951728, -3.69365125],
#        [ 1.53562163,  2.35152982],
#        [-5.11274001, -2.518096  ],
#        [-0.70190755,  4.34165026],
#        [ 0.23636692,  3.42091306],
#        [-5.02008618, -2.43785829],
#        [-5.35680941, -2.76178606],
#        [ 0.30224436,  2.74551396],
#        [-3.84290908, -4.04303245],
#        [ 1.73389013, -4.41019901],
#        [ 1.29466712, -5.01016711],
#        [ 0.87363943,  5.11507427],
#        [-0.75882452, -6.44901718],
#        [-3.48494251, -3.8169033 ],
#        [-1.84925614, -4.77109017],
#        [-1.59291452,  4.27488137],
#        [-3.99159224, -2.37871917],
#        [ 0.82962084, -5.65774393],
#        [-2.5860894 , -3.4950184 ],
#        [-3.32622971, -3.88502784],
#        [ 0.40662774, -5.37694734],
#        [-0.55847652, -3.86792941],
#        [ 0.63804241, -3.91279515],
#        [ 0.15620296, -4.95152011],
#        [-2.69932584, -1.7998378 ],
#        [-0.56649946,  2.70065341],
#        [-3.12369446, -3.73807086],
#        [-0.23131645, -5.35849206],
#        [ 1.21983872,  0.91703883],
#        [-2.81436471, -2.0240186 ],
#        [-0.08948381,  3.83816865],
#        [ 1.28294287,  4.6542061 ],
#        [-0.05613115, -3.21798178],
#        [ 0.71998903,  3.38649992],
#        [-3.0160051 , -2.72525466],
#        [-5.18101408, -1.92869617],
#        [ 0.87843413, -3.89779662],
#        [-0.01279861,  3.66558708],
#        [ 0.23448003, -3.28468317],
#        [-1.98923556, -2.29693562],
#        [-2.69749615, -2.79481156],
#        [ 0.63444621,  4.05947454],
#        [ 0.37527442,  3.80095879],
#        [-0.64329135, -6.42763383],
#        [-0.77660305,  3.73550004],
#        [-1.79499052, -5.59026846],
#        [ 0.40737531, -5.05330003],
#        [-4.68671118, -2.88219909],
#        [-1.97247834, -5.44372729],
#        [-2.41325388, -2.30524874],
#        [ 0.16504822, -2.85601139],
#        [-0.1131188 ,  2.96375148],
#        [-1.47922282,  6.30027028],
#        [-1.30589989, -4.88854646],
#        [-0.18727568,  4.34322518],
#        [-4.77918515, -5.30339608],
#        [-0.43359955,  3.90406113],
#        [-4.97361135, -3.18484479],
#        [-1.0349231 , -5.10012296],
#        [ 0.30171245,  3.86228401],
#        [-3.7003059 , -3.97379119],
#        [-0.12391338, -5.66970925],
#        [-4.2820512 , -3.07700832],
#        [-0.74503576, -4.63387109],
#        [-5.51609442, -3.21399289],
#        [-0.90175313,  3.47948947],
#        [-0.04396436,  3.90662757],
#        [-4.1680955 , -3.74863969],
#        [-0.92658081, -3.87962385],
#        [-1.14187471, -3.40770857],
#        [-1.28114183, -3.00927883],
#        [ 0.12331421,  4.70796213],
#        [-0.37658216, -5.44044767],
#        [-0.50610238, -5.04969669],
#        [ 0.4456108 , -4.87154792],
#        [-0.42076812,  4.29479708],
#        [-4.9272065 , -3.09863347],
#        [ 0.01180643,  3.40734754],
#        [-1.8300861 ,  3.06896736],
#        [-0.76151658,  3.21063329],
#        [ 0.3383577 ,  5.05128549],
#        [ 0.2345589 ,  5.04024649],
#        [ 1.20662537, -2.45170644],
#        [-4.41347731, -3.60012378],
#        [-3.36431629, -3.59421977],
#        [-3.06927729, -3.12222954],
#        [ 0.42372653,  3.58296026],
#        [-1.3416917 , -3.19169724],
#        [ 0.23997517,  2.96651903],
#        [-6.19631057, -2.18803491],
#        [-2.94314748, -2.07597315],
#        [ 0.55604874,  4.46451438],
#        [-5.97574812, -2.11858287],
#        [-1.39133349, -3.63152456],
#        [-0.89282943,  4.15943286],
#        [-0.5985992 , -4.36880028],
#        [-3.75316381, -2.71240322],
#        [-1.71377147, -5.48676543]])

# %%
kmeans = KMeans(5)

kmeans.fit(X)

y_ = kmeans.predict(X)

y_

plt.scatter(X[:,0],X[:,1],c = y_)

# %%
kmeans = KMeans(3)

kmeans.fit(X)

y_ = kmeans.predict(X)

y_

plt.scatter(X[:,0],X[:,1],c = y_)

# %%
# 分類係數--轮廓系数

# %%
from sklearn.metrics import silhouette_score

# %%
kmeans = KMeans(3)

kmeans.fit(X)

y_ = kmeans.predict(X)

y_

plt.scatter(X[:,0],X[:,1],c = y_)
silhouette_score(X,y_)

'''The Silhouette Coefficient is calculated using the mean intra-cluster
distance (``a``)(簇內距離) and the mean nearest-cluster distance (``b``)(各簇距離) for each
sample.  The Silhouette Coefficient for a sample is ``(b - a) / max(a,
b)``.  To clarify, ``b`` is the distance between a sample and the nearest
cluster that the sample is not a part of.
Note that Silhouette Coefficient is only defined if number of labels
is ``2 <= n_labels <= n_samples - 1``.'''
# Out:
# 'The Silhouette Coefficient is calculated using the mean intra-cluster\ndistance (``a``)(簇內距離) and the mean nearest-cluster distance (``b``)(各簇距離) for each\nsample.  The Silhouette Coefficient for a sample is ``(b - a) / max(a,\nb)``.  To clarify, ``b`` is the distance between a sample and the nearest\ncluster that the sample is not a part of.\nNote that Silhouette Coefficient is only defined if number of labels\nis ``2 <= n_labels <= n_samples - 1``.'
